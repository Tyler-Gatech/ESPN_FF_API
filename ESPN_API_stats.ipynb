# %%
from ff_espn_api import League
import requests
from collections import defaultdict
import sys
import pandas as pd
import numpy as np

from urllib.request import urlopen 
from bs4 import BeautifulSoup

game_id = '401012352'
url = 'http://site.api.espn.com/apis/site/v2/sports/football/college-football/summary?event='+game_id


r = requests.get(url, params='', cookies = '')
data = r.json()

# %%
for i in data['boxscore']['players']: 
        for x in i['statistics']:
            #z give you the values i statististic
            #print(x)
            #stat_type = x['name']
            #stat_team = x['text']
            #print(stat_type, stat_team)
            for z in x['athletes']:
                print(z)
            #    stat_type = x['name']
            #    print(z+"label", stat_type + " stat type", x[z])
                #for a in z:
                    #print(a)
                
        #for x in i['team']:
            #print(x)
                
                    
print(i['team']['id'])
# Out:
# {'athlete': {'id': '3917810', 'uid': 's:20~l:23~a:3917810', 'guid': 'd3095f49b0478d0dda8cb0dfba2ee5b1', 'displayName': 'TaQuon Marshall', 'links': [{'href': 'http://www.espn.com/college-football/player/_/id/3917810/taquon-marshall', 'text': 'Player Card'}, {'href': 'http://www.espn.com/college-football/player/stats/_/id/3917810/taquon-marshall', 'text': 'Stats'}, {'href': 'http://www.espn.com/college-football/player/splits/_/id/3917810/taquon-marshall', 'text': 'Splits'}, {'href': 'http://www.espn.com/college-football/player/gamelog/_/id/3917810/taquon-marshall', 'text': 'Game Log'}, {'href': 'http://www.espn.com/college-football/player/news/_/id/3917810/taquon-marshall', 'text': 'News'}, {'href': 'http://www.espn.com/college-football/player/bio/_/id/3917810/taquon-marshall', 'text': 'Bio'}, {'href': 'http://www.espn.com/college-football/player/_/id/3917810/taquon-marshall', 'text': 'Overview'}]}, 'stats': ['4/12', '69', '5.8', '1', '0', '4.7']}
# ...

# %%
#view each section available in the json file
for i in data:
    print("HEADER",i)
    for n in data[i]: 
        print("SUB", n)
# Out:
# HEADER boxscore
# SUB teams
# SUB players
# HEADER gameInfo
# SUB venue
# SUB attendance
# HEADER drives
# SUB previous
# HEADER leaders
# ...

# %%
#Go through the sections 1 by 1 and grab the relevant information
#start with boxscore

#What data is available in boxscore?
for i in data['boxscore']:
    print("boxscore",i)
#Results: teams, players

#What data is available in teams section
for i in data['boxscore']['teams']:
    for key,value in i.items():
        print("teams", key)
#Results teams,statistics
# Out:
# boxscore teams
# boxscore players
# teams team
# teams statistics
# teams team
# teams statistics

# %%
#We'll start with team info in the teams section, lets grab each teams info, 
#viewing the data
for i in data['boxscore']['teams']:
    print(i['team'])
# Out:
# {'id': '59', 'uid': 's:20~l:23~t:59', 'slug': 'georgia-tech-yellow-jackets', 'location': 'Georgia Tech', 'name': 'Yellow Jackets', 'abbreviation': 'GT', 'displayName': 'Georgia Tech Yellow Jackets', 'shortDisplayName': 'Yellow Jackets', 'color': '00223e', 'alternateColor': '002c56', 'logo': 'https://a.espncdn.com/i/teamlogos/ncaa/500/59.png'}
# {'id': '61', 'uid': 's:20~l:23~t:61', 'slug': 'georgia-bulldogs', 'location': 'Georgia', 'name': 'Bulldogs', 'abbreviation': 'UGA', 'displayName': 'Georgia Bulldogs', 'shortDisplayName': 'Bulldogs', 'color': 'CC0000', 'alternateColor': '000000', 'logo': 'https://a.espncdn.com/i/teamlogos/ncaa/500/61.png'}

# %%
#let's save this as a pandas dataframe

team0 = dict(data['boxscore']['teams'][0]['team'])
df0 = pd.DataFrame(list(team0.items())).T

team1 = dict(data['boxscore']['teams'][1]['team'])
df1 = pd.DataFrame(list(team1.items())).T

df_teams = pd.concat([df0.iloc[[1]], df1.iloc[[1]]])

#Grab the first row from df0 to set as column names
column_names = df0.iloc[[0]].values.tolist()
df_teams.columns = column_names


#print(list(new_data.items()))
#print(pd.DataFrame(list(new_data.items())).T).iloc([1])
print(df_teams)
#print(df2.iloc[[1]])
#df.loc[2] =
# Out:
#    id             uid                         slug      location  \
# 1  59  s:20~l:23~t:59  georgia-tech-yellow-jackets  Georgia Tech
# 1  61  s:20~l:23~t:61             georgia-bulldogs       Georgia
#
#              name abbreviation                  displayName shortDisplayName  \
# 1  Yellow Jackets           GT  Georgia Tech Yellow Jackets   Yellow Jackets
# 1        Bulldogs          UGA             Georgia Bulldogs         Bulldogs
#
#     color alternateColor                                               logo
# 1  00223e         002c56  https://a.espncdn.com/i/teamlogos/ncaa/500/59.png
# 1  CC0000         000000  https://a.espncdn.com/i/teamlogos/ncaa/500/61.png

# %%
#Create an initial blank data frame
df_team_stats = pd.DataFrame(data=None)

for i in data['boxscore']['teams']:
    new_df = pd.DataFrame(i['statistics'])
    new_df = new_df.assign(team_id = i['team']['id'])
    new_df = new_df.assign(game_id = game_id)
    df_team_stats = pd.concat([df_team_stats,new_df])
    

#the initial data frame
print("LONG VIEW", df_team_stats)

#We can flip this to make it more compact
df_team_stats = df_team_stats.pivot_table(index = ['team_id','game_id'],columns='label', values='displayValue',  aggfunc='first').reset_index()

print ("COMPACT VIEW", df_team_stats)
# Out:
# LONG VIEW    displayValue                 label                 name team_id    game_id
# 0            12             1st Downs           firstDowns      59  401012352
# 1          3-13   3rd down efficiency         thirdDownEff      59  401012352
# 2           3-6   4th down efficiency        fourthDownEff      59  401012352
# 3           219           Total Yards           totalYards      59  401012352
# 4            91               Passing      netPassingYards      59  401012352
# 5          5-14              Comp-Att   completionAttempts      59  401012352
# 6           6.5        Yards per pass         yardsPerPass      59  401012352
# 7           128               Rushing         rushingYards      59  401012352
# 8            46      Rushing Attempts      rushingAttempts      59  401012352
# 9           2.8        Yards per rush  yardsPerRushAttempt      59  401012352
# 10         2-20             Penalties  totalPenaltiesYards      59  401012352
# ...

# %%
#the next section in the call is boxscore players stats, let's determine the possible sections of stats

stat_sections = set()

for i in data['boxscore']['players']:
    for a in i['statistics']:
        stat_sections.add(a['name'])
        
print(stat_sections)
# Out:
# {'interceptions', 'receiving', 'punting', 'kickReturns', 'kicking', 'defensive', 'fumbles', 'puntReturns', 'rushing', 'passing'}

# %%
# Out:
# {'yo': 'a'}
# 4379396

# %%
#the next section in the call is boxscore players stats. First I want to develop a player database
athlete_list = []

for i in data['boxscore']['players']:
    for a in i['statistics']:
        for z in a['athletes']:
            #this is troubleshooting for erroneous ids which are negatives
            if(pd.to_numeric(z['athlete']['id'])) > 0:
                athlete_dict = dict()
                athlete_dict['id'] = z['athlete']['id']
                athlete_dict['name'] = z['athlete']['displayName']
                athlete_dict['guid'] = z['athlete']['guid']
                athlete_dict['link'] = z['athlete']['links'][0]['href']
                athlete_list.append(athlete_dict)

athlete_df = pd.DataFrame(athlete_list)

print(athlete_df[:5])
# Out:
#                                guid       id  \
# 0  d3095f49b0478d0dda8cb0dfba2ee5b1  3917810
# 1  741da6a62d3356ebc470266aa1e7273c  4360578
# 2  f46a3fce74c6755efb0364d2c2447423  4240482
# 3  718c5787faececdbfd68870663fd0bc7  4240481
# 4  d3095f49b0478d0dda8cb0dfba2ee5b1  3917810
#
#                                                 link              name
# 0  http://www.espn.com/college-football/player/_/...   TaQuon Marshall
# 1  http://www.espn.com/college-football/player/_/...      James Graham
# 2  http://www.espn.com/college-football/player/_/...     Tobias Oliver
# 3  http://www.espn.com/college-football/player/_/...  Jerry Howard Jr.
# 4  http://www.espn.com/college-football/player/_/...   TaQuon Marshall

# %%
#Next we'll grab the data for each section of the stats category
print(stat_sections)
# Out:
# {'interceptions', 'receiving', 'punting', 'kickReturns', 'kicking', 'defensive', 'fumbles', 'puntReturns', 'rushing', 'passing'}

# %%
#the next section in the call is boxscore players stats
for i in data['boxscore']['players']:
    for a in i['statistics'][0]['name':
            #print(a)
            #print(i['team']['id'])
            print(a)
            #print(a['text'])
            #print(a['labels'])
            #print(a['descriptions'])
            #for name in a['athletes']:
                #print(name)
                #print(name['athlete']['id'])
                #print(name['athlete']['guid'])
                #print(name['athlete']['displayName'])
                #print(name['stats'])
                #print(dict(zip(a['labels'],name['stats'])))
                #stat_d = dict(zip(a['labels'],name['stats']))
                #stat_df = pd.DataFrame(list(stat_d.items())).T
                #print(stat_df)
            #print(a['stats'])
    #print(pd.DataFrame(i['statistics']))
    
#There are 6 elements: 
#name
#text
#labels
#descriptions
#athletes
#totals
    
#for i in data['boxscore']['teams']:
#    print(i['statistics'])
    #new_df = pd.DataFrame(i['statistics'])
# Out:
#   File "<ipython-input-326-44e2b6d17f33>", line 33
#     #new_df = pd.DataFrame(i['statistics'])
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
#now let's grab team statistics
#for i in data['boxscore']['teams']:
    #print(i)
    #new_df = pd.DataFrame(data['boxscore']['teams'][0]['statistics'])
    #new_df.assign(team_id='A')
    #print(new_df)
    #    print(i['team']['id'])
    # print(i['statistics'])
    #stat_data = i['statistics']
    #team_stats0 = i['statistics'][0]
    #df1 = pd.DataFrame(list(team_stats0.items())).T
#print(i['team']['id'])
    


#for d in stat_data:
#    print(d)
    
#df0 = pd.DataFrame(list(team0.items())).T

#l = data['boxscore']['teams'][0]['statistics']

#col_names = [d['name'] for d in l]
#row_data = [d['displayValue'] for d in l]
#[d['name'] for d in l]
# Out:
#   File "<ipython-input-198-3c52a0510120>", line 25
#     #[d['name'] for d in l]
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
#The first drive of the game, each play
for i in data['drives']['previous']:
    #Drive level information
    #print(i)
    #drive_id = i['id']
    #drive_plays = i['description'].split(',')[0].split()[0]
    #drive_yards = i['description'].split(',')[1].split()[0]
    #drive_time = i['description'].split(',')[2].split()[0]
    #drive_off_team = i['team']['displayName']
    #drive_st_clock = i['start']['clock']['displayValue']
    #drive_st_quarter = i['start']['period']['number']
    #drive_st_yds_to_ez = 100-i['start']['yardLine']
    #drive_score = i['isScore']
    #drive_off_plays = i['offensivePlays']
    #drive_result = i['result']
    
    #Play Level Information
    for x in i['plays']:

                    
        print(x)
    #print(drive_id, drive_plays, drive_yards, drive_time, drive_off_team,
    #      drive_st_clock, drive_st_quarter, drive_st_yds_to_gl, drive_score, drive_off_plays, drive_result)
        
        #play_id = x['id']
        #play_type = x['type']['id']
        #play_score = x['scoringPlay']
        #play_score_type = x['scoringType']['name']       
        #play_down = x['start']['down']
        #play_yds_to_go = x['start']['distance']
        #play_yds_to_ez = x['start']['yardsToEndzone']
        #play_yds = x['statYardage']
        #play_game_clock = x['clock']['displayValue']
        #play_away_score = x['awayScore']
        #play_home_score = x['homeScore']
        #play_text= x['text']
        #for z in x: 
        #    if z=='scoringType': 
        #        play_score_type = (x['scoringType']['name'])
        #    else:
        #        play_score_type = "none"
        #print(play_id, play_score_type)
        #print(play_id, play_type, play_score, play_down, play_yds_to_go, play_yds_to_ez, play_yds, 
        #play_game_clock, play_score_type, play_away_score, play_home_score,  play_text)
# Out:
# {'id': '401012352101849902', 'type': {'id': '53'}, 'text': 'Shawn Davis kickoff for 40 yds fair catch by Walter Grant at the Geo 25', 'awayScore': 0, 'homeScore': 0, 'period': {'number': 1}, 'clock': {'displayValue': '15:00'}, 'scoringPlay': False, 'priority': False, 'modified': '2018-11-24T17:02Z', 'wallclock': '2018-11-24T17:02:03Z', 'start': {'down': 1, 'distance': 10, 'yardLine': 65, 'yardsToEndzone': 65, 'team': {'id': '59'}}, 'end': {'down': 1, 'distance': 10, 'yardLine': 25, 'yardsToEndzone': 75, 'downDistanceText': '1st & 10 at UGA 25', 'shortDownDistanceText': '1st & 10', 'possessionText': 'UGA 25', 'team': {'id': '61'}}, 'statYardage': 0}
# ...

# %%
from ff_espn_api import League
import requests
from collections import defaultdict
import sys

from urllib.request import urlopen 
from bs4 import BeautifulSoup

url = 'https://api.foxsports.com/sportsdata/v1/live/cfb/games/29302.json?version=394&apikey=jE7yBJVRNAwdDesMgTzTXUUSx1It41Fq'

cff_dat = urlopen(url)

# %%
from ff_espn_api import League
import requests
from collections import defaultdict
import sys

from urllib.request import urlopen 
from bs4 import BeautifulSoup

event = '401012352'
link = 'http://site.api.espn.com/apis/site/v2/sports/football/college-football/summary?event='+event

url = urlopen(link)
content = url.read()
soup = BeautifulSoup(content)

# %%
soup['boxscore']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-ba46434fd987> in <module>
# ----> 1 soup['boxscore']
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#     969         """tag[key] returns the value of the 'key' attribute for the tag,
#     970         and throws an exception if it's not there."""
# --> 971         return self.attrs[key]
#     972
#     973     def __iter__(self):
#
# KeyError: 'boxscore'
